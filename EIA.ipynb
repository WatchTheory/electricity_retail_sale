# %% [markdown]
# <a href="https://colab.research.google.com/github/WatchTheory/electricity_retail_sale/blob/main/EIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import sheets # importing from google

import numpy as np
import pandas as pd   # importing pandas libraries

# %%
# # Replace with your google sheet's URL
sheet_url = "https://docs.google.com/spreadsheets/d/1XS1qv0Tc6dHxRD757QTfhroUi0mROJ142rVZlL6YJA8/edit?gid=670989619#gid=670989619 "
sheet = sheets.InteractiveSheet(url=sheet_url)            # Create interactive shees with url

# %%
# Convert the sheet data to a Pandas DataFrame
eia_data = sheet.as_df()

# %%
eia_data.head() # Display head of dataset
# Out:
#     period stateid stateDescription sectorid   sectorName customers  price  \
# 0  2023-08      NM       New Mexico      COM   commercial    146669  11.34
# 1  2023-08      SC   South Carolina      IND   industrial      3649   7.11
# 2  2023-08     NEW      New England      IND   industrial     21644   15.7
# 3  2023-08     NEW      New England      COM   commercial    945664  18.98
# 4  2023-08     NEW      New England      ALL  all sectors   7546862  22.18
#
#       revenue        sales      customers-units             price-units  \
# 0   107.92698     951.3902  number of customers  cents per kilowatthour
# 1   164.45787   2311.44491  number of customers  cents per kilowatthour
# 2   206.81166    1317.4741  number of customers  cents per kilowatthour
# 3   847.55768   4465.04926  number of customers  cents per kilowatthour
# 4  2328.05881  10494.39158  number of customers  cents per kilowatthour
#
#      revenue-units            sales-units
# ...
